# %% [markdown]
# # Practice Lab: Measures of Central Tendency

# %% [markdown]
# 1. Load in the relevant dataset using csv DictReader. The path has been provided.

# %%
import csv
path = './nhis.csv'

# Your code here
with open(path, 'r') as f:
    data = list(csv.DictReader(f))
data
# Out:
# [{'HHX': '16',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '33.36',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '74',
#   'weight': '260'},
#  {'HHX': '20',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '26.54',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '70',
#   'weight': '185'},
#  {'HHX': '69',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '32.13',
#   'SLEEP': '7',
#   'educ': '9',
#   'height': '61',
#   'weight': '170'},
#  {'HHX': '87',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '26.62',
#   'SLEEP': '8',
#   'educ': '14',
#   'height': '68',
#   'weight': '175'},
#  {'HHX': '88',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '27.13',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '66',
#   'weight': '168'},
#  {'HHX': '99',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '99.99',
#   'SLEEP': '98',
#   'educ': '12',
#   'height': '98',
#   'weight': '998'},
#  {'HHX': '101',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '99.99',
#   'SLEEP': '6',
#   'educ': '13',
#   'height': '99',
#   'weight': '172'},
#  {'HHX': '122',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '24.39',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '70',
#   'weight': '170'},
#  {'HHX': '129',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '24.47',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '65',
#   'weight': '147'},
#  {'HHX': '134',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '25.38',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '64',
#   'weight': '148'},
#  {'HHX': '162',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '23.3',
#   'SLEEP': '9',
#   'educ': '9',
#   'height': '65',
#   'weight': '140'},
#  {'HHX': '186',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '27.45',
#   'SLEEP': '7',
#   'educ': '6',
#   'height': '66',
#   'weight': '170'},
#  {'HHX': '194',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '99.99',
#   'SLEEP': '9',
#   'educ': '12',
#   'height': '99',
#   'weight': '130'},
#  {'HHX': '196',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '38.76',
#   'SLEEP': '6',
#   'educ': '13',
#   'height': '61',
#   'weight': '205'},
#  {'HHX': '197',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '34.97',
#   'SLEEP': '9',
#   'educ': '8',
#   'height': '61',
#   'weight': '185'},
#  {'HHX': '202',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '23.3',
#   'SLEEP': '5',
#   'educ': '13',
#   'height': '65',
#   'weight': '140'},
#  {'HHX': '205',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '23.57',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '68',
#   'weight': '155'},
#  {'HHX': '223',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '22.32',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '64',
#   'weight': '130'},
#  {'HHX': '225',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '27.46',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '64',
#   'weight': '160'},
#  {'HHX': '232',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '21',
#   'SLEEP': '6',
#   'educ': '19',
#   'height': '66',
#   'weight': '130'},
#  {'HHX': '234',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '25.82',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '67',
#   'weight': '165'},
#  {'HHX': '237',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '39.31',
#   'SLEEP': '8',
#   'educ': '14',
#   'height': '72',
#   'weight': '290'},
#  {'HHX': '250',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '23.63',
#   'SLEEP': '7',
#   'educ': '6',
#   'height': '61',
#   'weight': '125'},
#  {'HHX': '264',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '48.85',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '270',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '29.13',
#   'SLEEP': '4',
#   'educ': '13',
#   'height': '65',
#   'weight': '175'},
#  {'HHX': '285',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '19.84',
#   'SLEEP': '8',
#   'educ': '18',
#   'height': '61',
#   'weight': '105'},
#  {'HHX': '299',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '22.93',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '66',
#   'weight': '142'},
#  {'HHX': '306',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '27.46',
#   'SLEEP': '4',
#   'educ': '4',
#   'height': '64',
#   'weight': '160'},
#  {'HHX': '328',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '29.15',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '72',
#   'weight': '215'},
#  {'HHX': '344',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '27.46',
#   'SLEEP': '6',
#   'educ': '18',
#   'height': '64',
#   'weight': '160'},
#  {'HHX': '362',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '22.32',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '64',
#   'weight': '130'},
#  {'HHX': '363',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '28.61',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '71',
#   'weight': '205'},
#  {'HHX': '380',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '31.73',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '64',
#   'weight': '185'},
#  {'HHX': '381',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '30.52',
#   'SLEEP': '9',
#   'educ': '12',
#   'height': '72',
#   'weight': '225'},
#  {'HHX': '388',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '29.99',
#   'SLEEP': '6',
#   'educ': '13',
#   'height': '70',
#   'weight': '209'},
#  {'HHX': '410',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '37.95',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '66',
#   'weight': '235'},
#  {'HHX': '411',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '17.97',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '74',
#   'weight': '140'},
#  {'HHX': '422',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '27.41',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '76',
#   'weight': '225'},
#  {'HHX': '424',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '27.36',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '68',
#   'weight': '180'},
#  {'HHX': '429',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '22.29',
#   'SLEEP': '8',
#   'educ': '10',
#   'height': '66',
#   'weight': '138'},
#  {'HHX': '439',
#   'FMX': '1',
#   'FPX': '3',
#   'SEX': '2',
#   'BMI': '32.29',
#   'SLEEP': '99',
#   'educ': '12',
#   'height': '66',
#   'weight': '200'},
#  {'HHX': '443',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '34.69',
#   'SLEEP': '10',
#   'educ': '12',
#   'height': '69',
#   'weight': '235'},
#  {'HHX': '492',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '32.13',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '61',
#   'weight': '170'},
#  {'HHX': '520',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '36.88',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '64',
#   'weight': '215'},
#  {'HHX': '560',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '21.79',
#   'SLEEP': '8',
#   'educ': '18',
#   'height': '66',
#   'weight': '135'},
#  {'HHX': '560',
#   'FMX': '2',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '18.45',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '69',
#   'weight': '125'},
#  {'HHX': '569',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '23.43',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '66',
#   'weight': '145'},
#  {'HHX': '602',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '23.72',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '71',
#   'weight': '170'},
#  {'HHX': '616',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '28.61',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '71',
#   'weight': '205'},
#  {'HHX': '619',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '20.39',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '63',
#   'weight': '115'},
#  {'HHX': '629',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '26.62',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '68',
#   'weight': '175'},
#  {'HHX': '647',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '18.74',
#   'SLEEP': '8',
#   'educ': '21',
#   'height': '75',
#   'weight': '150'},
#  {'HHX': '660',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '30.86',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '64',
#   'weight': '180'},
#  {'HHX': '664',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '21.93',
#   'SLEEP': '6',
#   'educ': '7',
#   'height': '62',
#   'weight': '120'},
#  {'HHX': '665',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '50.27',
#   'SLEEP': '6',
#   'educ': '14',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '668',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '24.14',
#   'SLEEP': '7',
#   'educ': '99',
#   'height': '65',
#   'weight': '145'},
#  {'HHX': '681',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '32.94',
#   'SLEEP': '8',
#   'educ': '14',
#   'height': '64',
#   'weight': '192'},
#  {'HHX': '686',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '31.26',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '60',
#   'weight': '160'},
#  {'HHX': '693',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '23.78',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '62',
#   'weight': '130'},
#  {'HHX': '698',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '26.47',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '61',
#   'weight': '140'},
#  {'HHX': '729',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '30.12',
#   'SLEEP': '9',
#   'educ': '11',
#   'height': '63',
#   'weight': '170'},
#  {'HHX': '733',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '32.55',
#   'SLEEP': '8',
#   'educ': '18',
#   'height': '72',
#   'weight': '240'},
#  {'HHX': '746',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '29.83',
#   'SLEEP': '8',
#   'educ': '18',
#   'height': '72',
#   'weight': '220'},
#  {'HHX': '750',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '19.49',
#   'SLEEP': '7',
#   'educ': '9',
#   'height': '63',
#   'weight': '110'},
#  {'HHX': '762',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '27.41',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '67',
#   'weight': '175'},
#  {'HHX': '766',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '29.13',
#   'SLEEP': '6',
#   'educ': '18',
#   'height': '65',
#   'weight': '175'},
#  {'HHX': '774',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '27.12',
#   'SLEEP': '8',
#   'educ': '6',
#   'height': '64',
#   'weight': '158'},
#  {'HHX': '785',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '34.01',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '61',
#   'weight': '180'},
#  {'HHX': '809',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '19.05',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '66',
#   'weight': '118'},
#  {'HHX': '826',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '32.1',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '65',
#   'weight': '193'},
#  {'HHX': '839',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '28.73',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '68',
#   'weight': '189'},
#  {'HHX': '889',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '22.32',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '64',
#   'weight': '130'},
#  {'HHX': '894',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '23.01',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '71',
#   'weight': '165'},
#  {'HHX': '913',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '19.96',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '65',
#   'weight': '120'},
#  {'HHX': '921',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '24.81',
#   'SLEEP': '8',
#   'educ': '14',
#   'height': '63',
#   'weight': '140'},
#  {'HHX': '922',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '24.89',
#   'SLEEP': '6',
#   'educ': '11',
#   'height': '64',
#   'weight': '145'},
#  {'HHX': '931',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '27.11',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '72',
#   'weight': '200'},
#  {'HHX': '935',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '21.65',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '65',
#   'weight': '130'},
#  {'HHX': '941',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '24.27',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '71',
#   'weight': '174'},
#  {'HHX': '975',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '27.38',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '72',
#   'weight': '202'},
#  {'HHX': '978',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '29.16',
#   'SLEEP': '5',
#   'educ': '12',
#   'height': '64',
#   'weight': '170'},
#  {'HHX': '980',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '24.95',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '65',
#   'weight': '150'},
#  {'HHX': '1007',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '25.77',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '72',
#   'weight': '190'},
#  {'HHX': '1073',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '29.52',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '69',
#   'weight': '200'},
#  {'HHX': '1076',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '21.65',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '66',
#   'weight': '134'},
#  {'HHX': '1080',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '23.15',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '64',
#   'weight': '135'},
#  {'HHX': '1092',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '30.56',
#   'SLEEP': '12',
#   'educ': '16',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '1097',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '23.89',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '66',
#   'weight': '148'},
#  {'HHX': '1104',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '99.99',
#   'SLEEP': '99',
#   'educ': '13',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '1127',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '26.55',
#   'SLEEP': '8',
#   'educ': '21',
#   'height': '69',
#   'weight': '180'},
#  {'HHX': '1128',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '21.92',
#   'SLEEP': '5',
#   'educ': '14',
#   'height': '67',
#   'weight': '140'},
#  {'HHX': '1134',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '35.53',
#   'SLEEP': '6',
#   'educ': '13',
#   'height': '66',
#   'weight': '220'},
#  {'HHX': '1143',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '24.61',
#   'SLEEP': '5',
#   'educ': '16',
#   'height': '59',
#   'weight': '122'},
#  {'HHX': '1151',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '19.55',
#   'SLEEP': '8',
#   'educ': '18',
#   'height': '60',
#   'weight': '100'},
#  {'HHX': '1154',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '24.67',
#   'SLEEP': '8',
#   'educ': '14',
#   'height': '62',
#   'weight': '135'},
#  {'HHX': '1161',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '27.27',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '70',
#   'weight': '190'},
#  {'HHX': '1166',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '21.76',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '61',
#   'weight': '115'},
#  {'HHX': '1170',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '21.79',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '66',
#   'weight': '135'},
#  {'HHX': '1175',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '99.99',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '97',
#   'weight': '997'},
#  {'HHX': '1179',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '15.92',
#   'SLEEP': '5',
#   'educ': '13',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '1189',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '36.56',
#   'SLEEP': '8',
#   'educ': '9',
#   'height': '62',
#   'weight': '200'},
#  {'HHX': '1195',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '19.57',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '67',
#   'weight': '125'},
#  {'HHX': '1198',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '32.89',
#   'SLEEP': '8',
#   'educ': '11',
#   'height': '59',
#   'weight': '163'},
#  {'HHX': '1207',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '30.15',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '70',
#   'weight': '210'},
#  {'HHX': '1211',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '25.03',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '66',
#   'weight': '155'},
#  {'HHX': '1226',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '25.4',
#   'SLEEP': '10',
#   'educ': '6',
#   'height': '60',
#   'weight': '130'},
#  {'HHX': '1232',
#   'FMX': '1',
#   'FPX': '3',
#   'SEX': '1',
#   'BMI': '33.46',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '68',
#   'weight': '220'},
#  {'HHX': '1237',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '29.76',
#   'SLEEP': '6',
#   'educ': '13',
#   'height': '67',
#   'weight': '190'},
#  {'HHX': '1258',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '18.31',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '65',
#   'weight': '110'},
#  {'HHX': '1266',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '27.9',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '71',
#   'weight': '200'},
#  {'HHX': '1268',
#   'FMX': '1',
#   'FPX': '3',
#   'SEX': '2',
#   'BMI': '22.7',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '63',
#   'weight': '128'},
#  {'HHX': '1270',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '28.36',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '63',
#   'weight': '160'},
#  {'HHX': '1279',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '23.32',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '71',
#   'weight': '167'},
#  {'HHX': '1292',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '21.92',
#   'SLEEP': '6',
#   'educ': '18',
#   'height': '67',
#   'weight': '140'},
#  {'HHX': '1302',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '28.29',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '65',
#   'weight': '170'},
#  {'HHX': '1304',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '34.71',
#   'SLEEP': '6',
#   'educ': '13',
#   'height': '66',
#   'weight': '215'},
#  {'HHX': '1329',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '19.37',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '66',
#   'weight': '120'},
#  {'HHX': '1357',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '24.39',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '70',
#   'weight': '170'},
#  {'HHX': '1358',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '25.85',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '68',
#   'weight': '170'},
#  {'HHX': '1368',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '42.36',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '64',
#   'weight': '247'},
#  {'HHX': '1376',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '32.9',
#   'SLEEP': '7',
#   'educ': '5',
#   'height': '62',
#   'weight': '180'},
#  {'HHX': '1390',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '41.42',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '60',
#   'weight': '212'},
#  {'HHX': '1398',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '22.43',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '73',
#   'weight': '170'},
#  {'HHX': '1414',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '24.04',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '68',
#   'weight': '158'},
#  {'HHX': '1446',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '25.6',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '62',
#   'weight': '140'},
#  {'HHX': '1447',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '46.14',
#   'SLEEP': '8',
#   'educ': '8',
#   'height': '61',
#   'weight': '244'},
#  {'HHX': '1456',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '27.44',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '65',
#   'weight': '165'},
#  {'HHX': '1466',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '31.51',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '66',
#   'weight': '195'},
#  {'HHX': '1501',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '35.33',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '64',
#   'weight': '206'},
#  {'HHX': '1506',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '26.74',
#   'SLEEP': '7',
#   'educ': '6',
#   'height': '60',
#   'weight': '137'},
#  {'HHX': '1510',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '32.71',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '59',
#   'weight': '162'},
#  {'HHX': '1534',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '35.93',
#   'SLEEP': '9',
#   'educ': '11',
#   'height': '61',
#   'weight': '190'},
#  {'HHX': '1540',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '24.81',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '63',
#   'weight': '140'},
#  {'HHX': '1550',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '99.99',
#   'SLEEP': '8',
#   'educ': '3',
#   'height': '98',
#   'weight': '160'},
#  {'HHX': '1560',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '23.42',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '60',
#   'weight': '120'},
#  {'HHX': '1566',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '25.6',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '62',
#   'weight': '140'},
#  {'HHX': '1569',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '25.7',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '63',
#   'weight': '145'},
#  {'HHX': '1571',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '24.14',
#   'SLEEP': '8',
#   'educ': '18',
#   'height': '65',
#   'weight': '145'},
#  {'HHX': '1588',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '27.36',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '68',
#   'weight': '180'},
#  {'HHX': '1592',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '33.9',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '72',
#   'weight': '250'},
#  {'HHX': '1620',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '22.72',
#   'SLEEP': '8',
#   'educ': '97',
#   'height': '67',
#   'weight': '145'},
#  {'HHX': '1693',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '37.96',
#   'SLEEP': '6',
#   'educ': '13',
#   'height': '72',
#   'weight': '280'},
#  {'HHX': '1716',
#   'FMX': '2',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '35.53',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '66',
#   'weight': '220'},
#  {'HHX': '1736',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '31.17',
#   'SLEEP': '8',
#   'educ': '14',
#   'height': '61',
#   'weight': '165'},
#  {'HHX': '1749',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '27.78',
#   'SLEEP': '7',
#   'educ': '0',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '1753',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '28.29',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '64',
#   'weight': '165'},
#  {'HHX': '1760',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '58.52',
#   'SLEEP': '9',
#   'educ': '11',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '1771',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '25.72',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '64',
#   'weight': '150'},
#  {'HHX': '1772',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '23.72',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '71',
#   'weight': '170'},
#  {'HHX': '1776',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '31.18',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '72',
#   'weight': '230'},
#  {'HHX': '1783',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '26.63',
#   'SLEEP': '9',
#   'educ': '12',
#   'height': '65',
#   'weight': '160'},
#  {'HHX': '1790',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '25.06',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '67',
#   'weight': '160'},
#  {'HHX': '1792',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '27.31',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '63',
#   'weight': '154'},
#  {'HHX': '1799',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '30.11',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '68',
#   'weight': '198'},
#  {'HHX': '1802',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '28.29',
#   'SLEEP': '8',
#   'educ': '8',
#   'height': '65',
#   'weight': '170'},
#  {'HHX': '1825',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '28.54',
#   'SLEEP': '5',
#   'educ': '9',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '1834',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '23.72',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '71',
#   'weight': '170'},
#  {'HHX': '1852',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '23.78',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '62',
#   'weight': '130'},
#  {'HHX': '1857',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '28.64',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '69',
#   'weight': '194'},
#  {'HHX': '1876',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '22.32',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '64',
#   'weight': '130'},
#  {'HHX': '1907',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '24.21',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '66',
#   'weight': '150'},
#  {'HHX': '1909',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '23.05',
#   'SLEEP': '6',
#   'educ': '14',
#   'height': '63',
#   'weight': '130'},
#  {'HHX': '1929',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '28.34',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '67',
#   'weight': '181'},
#  {'HHX': '1932',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '26.55',
#   'SLEEP': '7',
#   'educ': '6',
#   'height': '69',
#   'weight': '180'},
#  {'HHX': '1937',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '25.21',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '66',
#   'weight': '156'},
#  {'HHX': '1953',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '20.8',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '61',
#   'weight': '110'},
#  {'HHX': '1962',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '24.34',
#   'SLEEP': '8',
#   'educ': '4',
#   'height': '68',
#   'weight': '160'},
#  {'HHX': '1978',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '29.28',
#   'SLEEP': '7',
#   'educ': '8',
#   'height': '60',
#   'weight': '150'},
#  {'HHX': '1993',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '24.39',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '72',
#   'weight': '180'},
#  {'HHX': '2008',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '24.39',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '70',
#   'weight': '170'},
#  {'HHX': '2014',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '31.62',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '65',
#   'weight': '190'},
#  {'HHX': '2031',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '23.47',
#   'SLEEP': '7',
#   'educ': '19',
#   'height': '67',
#   'weight': '150'},
#  {'HHX': '2043',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '28.36',
#   'SLEEP': '10',
#   'educ': '18',
#   'height': '63',
#   'weight': '160'},
#  {'HHX': '2046',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '30.85',
#   'SLEEP': '9',
#   'educ': '13',
#   'height': '69',
#   'weight': '209'},
#  {'HHX': '2047',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '26.06',
#   'SLEEP': '8',
#   'educ': '8',
#   'height': '64',
#   'weight': '152'},
#  {'HHX': '2067',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '54.6',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '2077',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '25.06',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '67',
#   'weight': '160'},
#  {'HHX': '2084',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '23.74',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '74',
#   'weight': '185'},
#  {'HHX': '2137',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '19.19',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '62',
#   'weight': '105'},
#  {'HHX': '2140',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '26.26',
#   'SLEEP': '6',
#   'educ': '21',
#   'height': '69',
#   'weight': '178'},
#  {'HHX': '2145',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '37.11',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '60',
#   'weight': '190'},
#  {'HHX': '2152',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '22.43',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '73',
#   'weight': '170'},
#  {'HHX': '2161',
#   'FMX': '2',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '45.34',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '2166',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '21.92',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '67',
#   'weight': '140'},
#  {'HHX': '2169',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '99.99',
#   'SLEEP': '98',
#   'educ': '12',
#   'height': '98',
#   'weight': '998'},
#  {'HHX': '2202',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '22.29',
#   'SLEEP': '6',
#   'educ': '13',
#   'height': '62',
#   'weight': '122'},
#  {'HHX': '2231',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '23.63',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '69',
#   'weight': '160'},
#  {'HHX': '2233',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '27.46',
#   'SLEEP': '8',
#   'educ': '8',
#   'height': '64',
#   'weight': '160'},
#  {'HHX': '2268',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '33.46',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '68',
#   'weight': '220'},
#  {'HHX': '2272',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '29.95',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '72',
#   'weight': '221'},
#  {'HHX': '2275',
#   'FMX': '1',
#   'FPX': '3',
#   'SEX': '1',
#   'BMI': '29.51',
#   'SLEEP': '8',
#   'educ': '19',
#   'height': '74',
#   'weight': '230'},
#  {'HHX': '2277',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '27.11',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '72',
#   'weight': '200'},
#  {'HHX': '2282',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '24.02',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '64',
#   'weight': '140'},
#  {'HHX': '2283',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '25.85',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '66',
#   'weight': '160'},
#  {'HHX': '2288',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '22.8',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '68',
#   'weight': '150'},
#  {'HHX': '2295',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '27.44',
#   'SLEEP': '5',
#   'educ': '13',
#   'height': '65',
#   'weight': '165'},
#  {'HHX': '2300',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '27.42',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '61',
#   'weight': '145'},
#  {'HHX': '2312',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '25.09',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '69',
#   'weight': '170'},
#  {'HHX': '2325',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '23.72',
#   'SLEEP': '8',
#   'educ': '19',
#   'height': '71',
#   'weight': '170'},
#  {'HHX': '2328',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '28.27',
#   'SLEEP': '4',
#   'educ': '11',
#   'height': '66',
#   'weight': '175'},
#  {'HHX': '2334',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '21.65',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '65',
#   'weight': '130'},
#  {'HHX': '2342',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '36.51',
#   'SLEEP': '6',
#   'educ': '13',
#   'height': '68',
#   'weight': '240'},
#  {'HHX': '2350',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '20.47',
#   'SLEEP': '6',
#   'educ': '11',
#   'height': '65',
#   'weight': '123'},
#  {'HHX': '2363',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '21.29',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '68',
#   'weight': '140'},
#  {'HHX': '2376',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '20.08',
#   'SLEEP': '8',
#   'educ': '14',
#   'height': '68',
#   'weight': '132'},
#  {'HHX': '2384',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '25.77',
#   'SLEEP': '7',
#   'educ': '21',
#   'height': '72',
#   'weight': '190'},
#  {'HHX': '2393',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '23.95',
#   'SLEEP': '6',
#   'educ': '13',
#   'height': '62',
#   'weight': '131'},
#  {'HHX': '2431',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '19.55',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '60',
#   'weight': '100'},
#  {'HHX': '2453',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '28.34',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '72',
#   'weight': '209'},
#  {'HHX': '2456',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '28.61',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '71',
#   'weight': '205'},
#  {'HHX': '2459',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '23.3',
#   'SLEEP': '8',
#   'educ': '6',
#   'height': '65',
#   'weight': '140'},
#  {'HHX': '2481',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '21.93',
#   'SLEEP': '9',
#   'educ': '18',
#   'height': '62',
#   'weight': '120'},
#  {'HHX': '2493',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '34.66',
#   'SLEEP': '6',
#   'educ': '21',
#   'height': '74',
#   'weight': '270'},
#  {'HHX': '2503',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '26.52',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '71',
#   'weight': '190'},
#  {'HHX': '2504',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '25.06',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '67',
#   'weight': '160'},
#  {'HHX': '2519',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '24.75',
#   'SLEEP': '6',
#   'educ': '13',
#   'height': '67',
#   'weight': '158'},
#  {'HHX': '2527',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '23.43',
#   'SLEEP': '6',
#   'educ': '18',
#   'height': '66',
#   'weight': '145'},
#  {'HHX': '2546',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '30.26',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '69',
#   'weight': '205'},
#  {'HHX': '2548',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '20.37',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '67',
#   'weight': '130'},
#  {'HHX': '2553',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '24.21',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '66',
#   'weight': '150'},
#  {'HHX': '2571',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '30.26',
#   'SLEEP': '8',
#   'educ': '6',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '2592',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '21.7',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '72',
#   'weight': '160'},
#  {'HHX': '2593',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '26.97',
#   'SLEEP': '5',
#   'educ': '16',
#   'height': '65',
#   'weight': '162'},
#  {'HHX': '2596',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '35.55',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '61',
#   'weight': '188'},
#  {'HHX': '2604',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '23.57',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '68',
#   'weight': '155'},
#  {'HHX': '2616',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '99.99',
#   'SLEEP': '98',
#   'educ': '12',
#   'height': '98',
#   'weight': '998'},
#  {'HHX': '2617',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '26.15',
#   'SLEEP': '5',
#   'educ': '16',
#   'height': '68',
#   'weight': '172'},
#  {'HHX': '2632',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '23.66',
#   'SLEEP': '6',
#   'educ': '13',
#   'height': '70',
#   'weight': '165'},
#  {'HHX': '2642',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '22.06',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '68',
#   'weight': '145'},
#  {'HHX': '2652',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '25.81',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '70',
#   'weight': '180'},
#  {'HHX': '2655',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '27.5',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '71',
#   'weight': '197'},
#  {'HHX': '2658',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '33.28',
#   'SLEEP': '8',
#   'educ': '7',
#   'height': '65',
#   'weight': '200'},
#  {'HHX': '2667',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '29.52',
#   'SLEEP': '5',
#   'educ': '12',
#   'height': '69',
#   'weight': '200'},
#  {'HHX': '2669',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '99.99',
#   'SLEEP': '98',
#   'educ': '13',
#   'height': '98',
#   'weight': '998'},
#  {'HHX': '2680',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '33.46',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '68',
#   'weight': '220'},
#  {'HHX': '2697',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '28.69',
#   'SLEEP': '8',
#   'educ': '19',
#   'height': '70',
#   'weight': '200'},
#  {'HHX': '2702',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '99.99',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '67',
#   'weight': '999'},
#  {'HHX': '2723',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '37.11',
#   'SLEEP': '8',
#   'educ': '10',
#   'height': '60',
#   'weight': '190'},
#  {'HHX': '2738',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '41.6',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '65',
#   'weight': '250'},
#  {'HHX': '2744',
#   'FMX': '1',
#   'FPX': '3',
#   'SEX': '2',
#   'BMI': '29.96',
#   'SLEEP': '8',
#   'educ': '9',
#   'height': '63',
#   'weight': '169'},
#  {'HHX': '2759',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '23.09',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '74',
#   'weight': '180'},
#  {'HHX': '2776',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '26.62',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '67',
#   'weight': '170'},
#  {'HHX': '2778',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '29.76',
#   'SLEEP': '8',
#   'educ': '4',
#   'height': '67',
#   'weight': '190'},
#  {'HHX': '2803',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '24.26',
#   'SLEEP': '5',
#   'educ': '12',
#   'height': '63',
#   'weight': '137'},
#  {'HHX': '2806',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '31.17',
#   'SLEEP': '7',
#   'educ': '8',
#   'height': '67',
#   'weight': '199'},
#  {'HHX': '2808',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '31.01',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '69',
#   'weight': '210'},
#  {'HHX': '2820',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '19.67',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '2822',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '25.2',
#   'SLEEP': '8',
#   'educ': '9',
#   'height': '67',
#   'weight': '161'},
#  {'HHX': '2827',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '31.77',
#   'SLEEP': '6',
#   'educ': '13',
#   'height': '65',
#   'weight': '191'},
#  {'HHX': '2834',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '25.72',
#   'SLEEP': '8',
#   'educ': '14',
#   'height': '64',
#   'weight': '150'},
#  {'HHX': '2846',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '23.74',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '72',
#   'weight': '175'},
#  {'HHX': '2849',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '32.55',
#   'SLEEP': '6',
#   'educ': '14',
#   'height': '72',
#   'weight': '240'},
#  {'HHX': '2864',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '26.62',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '67',
#   'weight': '170'},
#  {'HHX': '2866',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '20.9',
#   'SLEEP': '8',
#   'educ': '14',
#   'height': '63',
#   'weight': '118'},
#  {'HHX': '2873',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '99.99',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '64',
#   'weight': '999'},
#  {'HHX': '2890',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '23.48',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '65',
#   'weight': '141'},
#  {'HHX': '2897',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '23.57',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '68',
#   'weight': '155'},
#  {'HHX': '2908',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '24.29',
#   'SLEEP': '8',
#   'educ': '6',
#   'height': '65',
#   'weight': '146'},
#  {'HHX': '2908',
#   'FMX': '2',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '25.72',
#   'SLEEP': '7',
#   'educ': '9',
#   'height': '64',
#   'weight': '150'},
#  {'HHX': '2920',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '99.99',
#   'SLEEP': '8',
#   'educ': '9',
#   'height': '99',
#   'weight': '999'},
#  {'HHX': '2934',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '31.39',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '64',
#   'weight': '183'},
#  {'HHX': '2949',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '19.84',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '61',
#   'weight': '105'},
#  {'HHX': '2986',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '29.28',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '60',
#   'weight': '150'},
#  {'HHX': '3011',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '28.16',
#   'SLEEP': '5',
#   'educ': '9',
#   'height': '63',
#   'weight': '159'},
#  {'HHX': '3013',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '31.01',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '69',
#   'weight': '210'},
#  {'HHX': '3022',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '49.78',
#   'SLEEP': '10',
#   'educ': '7',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '3040',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '42.21',
#   'SLEEP': '15',
#   'educ': '10',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '3054',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '29.16',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '64',
#   'weight': '170'},
#  {'HHX': '3058',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '24.39',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '70',
#   'weight': '170'},
#  {'HHX': '3099',
#   'FMX': '3',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '26.39',
#   'SLEEP': '8',
#   'educ': '6',
#   'height': '73',
#   'weight': '200'},
#  {'HHX': '3102',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '22.45',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '65',
#   'weight': '135'},
#  {'HHX': '3104',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '31.95',
#   'SLEEP': '9',
#   'educ': '14',
#   'height': '68',
#   'weight': '210'},
#  {'HHX': '3113',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '99.99',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '98',
#   'weight': '997'},
#  {'HHX': '3132',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '28.12',
#   'SLEEP': '6',
#   'educ': '7',
#   'height': '70',
#   'weight': '196'},
#  {'HHX': '3141',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '25.19',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '60',
#   'weight': '129'},
#  {'HHX': '3146',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '41.49',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '67',
#   'weight': '265'},
#  {'HHX': '3147',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '25.81',
#   'SLEEP': '8',
#   'educ': '18',
#   'height': '70',
#   'weight': '180'},
#  {'HHX': '3184',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '25.03',
#   'SLEEP': '6',
#   'educ': '10',
#   'height': '66',
#   'weight': '155'},
#  {'HHX': '3198',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '23.03',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '67',
#   'weight': '147'},
#  {'HHX': '3208',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '21.79',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '66',
#   'weight': '135'},
#  {'HHX': '3214',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '25.5',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '72',
#   'weight': '188'},
#  {'HHX': '3222',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '21.12',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '73',
#   'weight': '160'},
#  {'HHX': '3225',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '34.4',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '69',
#   'weight': '233'},
#  {'HHX': '3236',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '27.86',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '67',
#   'weight': '178'},
#  {'HHX': '3299',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '19.49',
#   'SLEEP': '4',
#   'educ': '21',
#   'height': '63',
#   'weight': '110'},
#  {'HHX': '3301',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '25.81',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '70',
#   'weight': '180'},
#  {'HHX': '3304',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '31.73',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '69',
#   'weight': '215'},
#  {'HHX': '3305',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '21.25',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '63',
#   'weight': '120'},
#  {'HHX': '3309',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '28.33',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '60',
#   'weight': '145'},
#  {'HHX': '3314',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '28.12',
#   'SLEEP': '7',
#   'educ': '21',
#   'height': '70',
#   'weight': '196'},
#  {'HHX': '3325',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '30.69',
#   'SLEEP': '7',
#   'educ': '9',
#   'height': '66',
#   'weight': '190'},
#  {'HHX': '3328',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '32.99',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '70',
#   'weight': '230'},
#  {'HHX': '3341',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '25.06',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '67',
#   'weight': '160'},
#  {'HHX': '3361',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '30.69',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '66',
#   'weight': '190'},
#  {'HHX': '3382',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '28.72',
#   'SLEEP': '8',
#   'educ': '5',
#   'height': '60',
#   'weight': '147'},
#  {'HHX': '3385',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '99.99',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '3387',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '24.34',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '69',
#   'weight': '165'},
#  {'HHX': '3405',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '23.78',
#   'SLEEP': '8',
#   'educ': '14',
#   'height': '62',
#   'weight': '130'},
#  {'HHX': '3406',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '28.17',
#   'SLEEP': '3',
#   'educ': '13',
#   'height': '67',
#   'weight': '180'},
#  {'HHX': '3413',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '28.29',
#   'SLEEP': '7',
#   'educ': '9',
#   'height': '64',
#   'weight': '165'},
#  {'HHX': '3422',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '27.11',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '72',
#   'weight': '200'},
#  {'HHX': '3423',
#   'FMX': '2',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '25.81',
#   'SLEEP': '9',
#   'educ': '13',
#   'height': '70',
#   'weight': '180'},
#  {'HHX': '3432',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '29.76',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '67',
#   'weight': '190'},
#  {'HHX': '3436',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '25.85',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '68',
#   'weight': '170'},
#  {'HHX': '3474',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '22.36',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '72',
#   'weight': '165'},
#  {'HHX': '3477',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '19.46',
#   'SLEEP': '6',
#   'educ': '14',
#   'height': '61',
#   'weight': '103'},
#  {'HHX': '3486',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '21.46',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '65',
#   'weight': '129'},
#  {'HHX': '3496',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '26.55',
#   'SLEEP': '6',
#   'educ': '11',
#   'height': '69',
#   'weight': '180'},
#  {'HHX': '3505',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '20.8',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '65',
#   'weight': '125'},
#  {'HHX': '3521',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '31.97',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '66',
#   'weight': '198'},
#  {'HHX': '3530',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '25.84',
#   'SLEEP': '9',
#   'educ': '13',
#   'height': '69',
#   'weight': '175'},
#  {'HHX': '3537',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '30.19',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '66',
#   'weight': '187'},
#  {'HHX': '3542',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '24.81',
#   'SLEEP': '8',
#   'educ': '14',
#   'height': '63',
#   'weight': '140'},
#  {'HHX': '3558',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '37.75',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '64',
#   'weight': '220'},
#  {'HHX': '3587',
#   'FMX': '1',
#   'FPX': '3',
#   'SEX': '2',
#   'BMI': '31.08',
#   'SLEEP': '8',
#   'educ': '8',
#   'height': '62',
#   'weight': '170'},
#  {'HHX': '3588',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '32.55',
#   'SLEEP': '10',
#   'educ': '14',
#   'height': '72',
#   'weight': '240'},
#  {'HHX': '3593',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '28.03',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '67',
#   'weight': '179'},
#  {'HHX': '3594',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '24.39',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '72',
#   'weight': '180'},
#  {'HHX': '3600',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '25.24',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '62',
#   'weight': '138'},
#  {'HHX': '3610',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '25.06',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '67',
#   'weight': '160'},
#  {'HHX': '3616',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '22.32',
#   'SLEEP': '6',
#   'educ': '11',
#   'height': '64',
#   'weight': '130'},
#  {'HHX': '3627',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '26.62',
#   'SLEEP': '9',
#   'educ': '16',
#   'height': '67',
#   'weight': '170'},
#  {'HHX': '3629',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '27.05',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '62',
#   'weight': '148'},
#  {'HHX': '3674',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '19.74',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '64',
#   'weight': '115'},
#  {'HHX': '3680',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '26.55',
#   'SLEEP': '6',
#   'educ': '14',
#   'height': '69',
#   'weight': '180'},
#  {'HHX': '3696',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '27.27',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '64',
#   'weight': '159'},
#  {'HHX': '3725',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '29.32',
#   'SLEEP': '7',
#   'educ': '4',
#   'height': '71',
#   'weight': '210'},
#  {'HHX': '3741',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
# ...
#   'weight': '205'},
#  {'HHX': '10070',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '28.69',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '70',
#   'weight': '200'},
#  {'HHX': '10074',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '23.72',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '71',
#   'weight': '170'},
#  {'HHX': '10081',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '23.71',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '10092',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '24.81',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '63',
#   'weight': '140'},
#  {'HHX': '10094',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '24.34',
#   'SLEEP': '8',
#   'educ': '18',
#   'height': '68',
#   'weight': '160'},
#  {'HHX': '10110',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '25.85',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '66',
#   'weight': '160'},
#  {'HHX': '10113',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '36.61',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '65',
#   'weight': '220'},
#  {'HHX': '10120',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '33.32',
#   'SLEEP': '6',
#   'educ': '10',
#   'height': '63',
#   'weight': '188'},
#  {'HHX': '10126',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '34.01',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '61',
#   'weight': '180'},
#  {'HHX': '10146',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '99.99',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '62',
#   'weight': '997'},
#  {'HHX': '10157',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '20.52',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '68',
#   'weight': '135'},
#  {'HHX': '10200',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '23.91',
#   'SLEEP': '6',
#   'educ': '10',
#   'height': '63',
#   'weight': '135'},
#  {'HHX': '10217',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '32.29',
#   'SLEEP': '6',
#   'educ': '6',
#   'height': '66',
#   'weight': '200'},
#  {'HHX': '10220',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '28.96',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '67',
#   'weight': '185'},
#  {'HHX': '10224',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '32.9',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '62',
#   'weight': '180'},
#  {'HHX': '10234',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '24.26',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '63',
#   'weight': '137'},
#  {'HHX': '10236',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '28.96',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '67',
#   'weight': '185'},
#  {'HHX': '10241',
#   'FMX': '2',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '99.99',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '68',
#   'weight': '997'},
#  {'HHX': '10254',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '25.72',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '64',
#   'weight': '150'},
#  {'HHX': '10286',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '99.99',
#   'SLEEP': '98',
#   'educ': '12',
#   'height': '98',
#   'weight': '998'},
#  {'HHX': '10295',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '24.5',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '69',
#   'weight': '166'},
#  {'HHX': '10304',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '22.61',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '66',
#   'weight': '140'},
#  {'HHX': '10319',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '27.22',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '61',
#   'weight': '144'},
#  {'HHX': '10320',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '28.36',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '63',
#   'weight': '160'},
#  {'HHX': '10324',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '28.05',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '69',
#   'weight': '190'},
#  {'HHX': '10330',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '21.79',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '64',
#   'weight': '127'},
#  {'HHX': '10335',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '32.6',
#   'SLEEP': '6',
#   'educ': '14',
#   'height': '64',
#   'weight': '190'},
#  {'HHX': '10364',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '23.74',
#   'SLEEP': '8',
#   'educ': '21',
#   'height': '72',
#   'weight': '175'},
#  {'HHX': '10367',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '18.26',
#   'SLEEP': '5',
#   'educ': '18',
#   'height': '66',
#   'weight': '113'},
#  {'HHX': '10396',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '41.03',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '60',
#   'weight': '210'},
#  {'HHX': '10418',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '99.99',
#   'SLEEP': '8',
#   'educ': '99',
#   'height': '65',
#   'weight': '999'},
#  {'HHX': '10451',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '25.04',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '74',
#   'weight': '195'},
#  {'HHX': '10484',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '30.41',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '68',
#   'weight': '200'},
#  {'HHX': '10487',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '37.68',
#   'SLEEP': '6',
#   'educ': '13',
#   'height': '71',
#   'weight': '270'},
#  {'HHX': '10498',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '22.86',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '62',
#   'weight': '125'},
#  {'HHX': '10505',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '20.99',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '65',
#   'weight': '126'},
#  {'HHX': '10508',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '38.44',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '63',
#   'weight': '217'},
#  {'HHX': '10524',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '26.63',
#   'SLEEP': '99',
#   'educ': '16',
#   'height': '65',
#   'weight': '160'},
#  {'HHX': '10530',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '48.65',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '10533',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '29.94',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '65',
#   'weight': '180'},
#  {'HHX': '10534',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '30.69',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '66',
#   'weight': '190'},
#  {'HHX': '10555',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '25.77',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '72',
#   'weight': '190'},
#  {'HHX': '10569',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '26.62',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '67',
#   'weight': '170'},
#  {'HHX': '10570',
#   'FMX': '1',
#   'FPX': '5',
#   'SEX': '2',
#   'BMI': '99.99',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '63',
#   'weight': '997'},
#  {'HHX': '10580',
#   'FMX': '1',
#   'FPX': '4',
#   'SEX': '2',
#   'BMI': '25.03',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '66',
#   'weight': '155'},
#  {'HHX': '10585',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '28.47',
#   'SLEEP': '6',
#   'educ': '13',
#   'height': '69',
#   'weight': '193'},
#  {'HHX': '10599',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '29.94',
#   'SLEEP': '9',
#   'educ': '6',
#   'height': '65',
#   'weight': '180'},
#  {'HHX': '10607',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '23.3',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '65',
#   'weight': '140'},
#  {'HHX': '10608',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '30.7',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '71',
#   'weight': '220'},
#  {'HHX': '10611',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '29.7',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '73',
#   'weight': '225'},
#  {'HHX': '10616',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '23.32',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '72',
#   'weight': '172'},
#  {'HHX': '10636',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '27.36',
#   'SLEEP': '8',
#   'educ': '9',
#   'height': '68',
#   'weight': '180'},
#  {'HHX': '10651',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '43.13',
#   'SLEEP': '8',
#   'educ': '14',
#   'height': '62',
#   'weight': '236'},
#  {'HHX': '10672',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '31.39',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '64',
#   'weight': '183'},
#  {'HHX': '10675',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '38.59',
#   'SLEEP': '8',
#   'educ': '10',
#   'height': '66',
#   'weight': '239'},
#  {'HHX': '10678',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '22.15',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '63',
#   'weight': '125'},
#  {'HHX': '10692',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '24.34',
#   'SLEEP': '9',
#   'educ': '16',
#   'height': '69',
#   'weight': '165'},
#  {'HHX': '10727',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '31.02',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '63',
#   'weight': '175'},
#  {'HHX': '10735',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '17.23',
#   'SLEEP': '8',
#   'educ': '18',
#   'height': '67',
#   'weight': '110'},
#  {'HHX': '10752',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '20.21',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '59',
#   'weight': '100'},
#  {'HHX': '10761',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '30.7',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '71',
#   'weight': '220'},
#  {'HHX': '10771',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '27.12',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '64',
#   'weight': '158'},
#  {'HHX': '10776',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '99.99',
#   'SLEEP': '7',
#   'educ': '6',
#   'height': '98',
#   'weight': '175'},
#  {'HHX': '10783',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '26.52',
#   'SLEEP': '6',
#   'educ': '13',
#   'height': '71',
#   'weight': '190'},
#  {'HHX': '10810',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '30.18',
#   'SLEEP': '7',
#   'educ': '14',
#   'height': '64',
#   'weight': '176'},
#  {'HHX': '10815',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '32.1',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '65',
#   'weight': '193'},
#  {'HHX': '10823',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '20.37',
#   'SLEEP': '9',
#   'educ': '12',
#   'height': '67',
#   'weight': '130'},
#  {'HHX': '10845',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '19.63',
#   'SLEEP': '5',
#   'educ': '14',
#   'height': '65',
#   'weight': '118'},
#  {'HHX': '10858',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '24.95',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '65',
#   'weight': '150'},
#  {'HHX': '10862',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '29.32',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '71',
#   'weight': '210'},
#  {'HHX': '10877',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '23.44',
#   'SLEEP': '6',
#   'educ': '16',
#   'height': '71',
#   'weight': '168'},
#  {'HHX': '10902',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '52.47',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '59',
#   'weight': '260'},
#  {'HHX': '10925',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '28.03',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '67',
#   'weight': '179'},
#  {'HHX': '10934',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '23.57',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '68',
#   'weight': '155'},
#  {'HHX': '10938',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '27.9',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '71',
#   'weight': '200'},
#  {'HHX': '10952',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '99.99',
#   'SLEEP': '98',
#   'educ': '16',
#   'height': '98',
#   'weight': '998'},
#  {'HHX': '10971',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '19.74',
#   'SLEEP': '7',
#   'educ': '6',
#   'height': '64',
#   'weight': '115'},
#  {'HHX': '10984',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '26.62',
#   'SLEEP': '8',
#   'educ': '11',
#   'height': '67',
#   'weight': '170'},
#  {'HHX': '10997',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '29.15',
#   'SLEEP': '10',
#   'educ': '13',
#   'height': '72',
#   'weight': '215'},
#  {'HHX': '11000',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '20.46',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '76',
#   'weight': '168'},
#  {'HHX': '11009',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '47.47',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '11013',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '99.99',
#   'SLEEP': '98',
#   'educ': '16',
#   'height': '98',
#   'weight': '998'},
#  {'HHX': '11056',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '21.02',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '72',
#   'weight': '155'},
#  {'HHX': '11060',
#   'FMX': '1',
#   'FPX': '6',
#   'SEX': '1',
#   'BMI': '31.95',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '68',
#   'weight': '210'},
#  {'HHX': '11061',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '27.46',
#   'SLEEP': '7',
#   'educ': '6',
#   'height': '64',
#   'weight': '160'},
#  {'HHX': '11105',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '20.66',
#   'SLEEP': '8',
#   'educ': '18',
#   'height': '69',
#   'weight': '140'},
#  {'HHX': '11117',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '21.98',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '64',
#   'weight': '128'},
#  {'HHX': '11118',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '24.67',
#   'SLEEP': '4',
#   'educ': '9',
#   'height': '62',
#   'weight': '135'},
#  {'HHX': '11120',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '99.99',
#   'SLEEP': '98',
#   'educ': '18',
#   'height': '98',
#   'weight': '998'},
#  {'HHX': '11123',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '29.32',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '71',
#   'weight': '210'},
#  {'HHX': '11130',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '31.18',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '72',
#   'weight': '230'},
#  {'HHX': '11133',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '23.78',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '62',
#   'weight': '130'},
#  {'HHX': '11144',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '99.99',
#   'SLEEP': '98',
#   'educ': '12',
#   'height': '98',
#   'weight': '998'},
#  {'HHX': '11148',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '28.06',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '71',
#   'weight': '201'},
#  {'HHX': '11169',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '22.88',
#   'SLEEP': '8',
#   'educ': '11',
#   'height': '69',
#   'weight': '155'},
#  {'HHX': '11181',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '32.94',
#   'SLEEP': '7',
#   'educ': '13',
#   'height': '65',
#   'weight': '198'},
#  {'HHX': '11185',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '26.93',
#   'SLEEP': '6',
#   'educ': '12',
#   'height': '64',
#   'weight': '157'},
#  {'HHX': '11191',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '27.94',
#   'SLEEP': '8',
#   'educ': '7',
#   'height': '60',
#   'weight': '143'},
#  {'HHX': '11195',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '28.49',
#   'SLEEP': '7',
#   'educ': '16',
#   'height': '72',
#   'weight': '210'},
#  {'HHX': '11197',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '17.96',
#   'SLEEP': '8',
#   'educ': '12',
#   'height': '96',
#   'weight': '996'},
#  {'HHX': '11220',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '24.02',
#   'SLEEP': '8',
#   'educ': '18',
#   'height': '64',
#   'weight': '140'},
#  {'HHX': '11239',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '1',
#   'BMI': '27.11',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '72',
#   'weight': '200'},
#  {'HHX': '11240',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '20.8',
#   'SLEEP': '7',
#   'educ': '18',
#   'height': '65',
#   'weight': '125'},
#  {'HHX': '11241',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '24.39',
#   'SLEEP': '7',
#   'educ': '12',
#   'height': '70',
#   'weight': '170'},
#  {'HHX': '11247',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '31.08',
#   'SLEEP': '6',
#   'educ': '10',
#   'height': '62',
#   'weight': '170'},
#  {'HHX': '11248',
#   'FMX': '1',
#   'FPX': '2',
#   'SEX': '2',
#   'BMI': '21.93',
#   'SLEEP': '8',
#   'educ': '14',
#   'height': '62',
#   'weight': '120'},
#  {'HHX': '11254',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '2',
#   'BMI': '22.61',
#   'SLEEP': '8',
#   'educ': '13',
#   'height': '66',
#   'weight': '140'},
#  {'HHX': '11262',
#   'FMX': '1',
#   'FPX': '1',
#   'SEX': '1',
#   'BMI': '26.46',
#   'SLEEP': '8',
#   'educ': '16',
#   'height': '72',
#   'weight': '195'},
#  ...]

# %% [markdown]
# 2. Extract values for the the variable height and save to a Python list called `height_list`. Convert the data type appropriately:

# %%
# Your code here. 
height_list = [int(row['height']) for row in data]

# %% [markdown]
# 3. Calculate the mean of the height data by explicitly calculating the sum over values and dividing by the number of data points.

# %%
# Your code here. 
height_mean = sum(height_list)/len(height_list)
height_mean
# Out:
# 69.57826541274817

# %% [markdown]
# 4. Calculate mean height using numpy.

# %%
# Your code here. 
import numpy as np

height_numpy = np.array(height_list)
height_numpy.mean()
# Out:
# 69.57826541274817

# %% [markdown]
# We have plotted a histogram of the resultant height data. There are clearly outliers in the data.

# %% [markdown]
# ![image](height_distribut.png)

# %% [markdown]
# 5. Is the mean the best measure for central tendency given these outliers? Explain your answer.

# %% [markdown]
# The mean is not the best measure here. The outlier will pull the mean up from the central, most probable part of the main distribution.

# %% [markdown]
# 6. Given knowledge of the distribution of the data and the presence of outliers, compute the relevant statistic (i.e. the mode or the median) reflecting central tendency. Use either the Counter object or numpy respectively for the statistic you have chosen.

# %%
# Your code here. 

# the median is the best statistic here and is much more stable to the outliers than the mean.
median_stat = np.median(height_numpy)
median_stat
# Out:
# 67.0

# %% [markdown]
# 7. There are cases where the extreme values are either erroneous data points or are not relevant to the aims of our analysis. Filtering outliers is useful in this case. Filter the heights_list by removing any values greater than 80. This value is set by inspection of the histogram above. Save this to a new list called filtered_heights_list

# %%
# Your code here. 

filtered_height_list = [height for height in height_list if height < 80 ]

# %% [markdown]
# 8. Compute the mean on the filtered_heights_list:

# %%
# Your code here. 
filtered_heights_mean = np.array(filtered_height_list).mean()
filtered_heights_mean
# Out:
# 66.85231193926846

# %% [markdown]
# 9. How does the mean of the data with outliers removed compare to the mean of the original data? How do both means compare to the median?

# %% [markdown]
# The mean on the filtered list is lower than the original mean. It lies close to the median on the original dataset. Quick inpection of the histogram shows that both the median of the original data and the mean of the data with outliers removed lie at the center of the main distribution of heights.

# %% [markdown]
# 10. Calculate the mode for height data. Complete the function below so that it returns a list of values – there may be more than one value – which have the highest frequency.

# %%
# Your code here. 

# Throughout this cell, replace None with appropriate code

def get_mode(data):

    # Create and populate frequency distribution
    frequency_dict = {}
    
    for height in data:
        # If an element is not in the dict, add it to the dict with value 1
        # If an element is already in the dict, +1 the value in place
        if height in frequency_dict.keys():
            frequency_dict[height] += 1
        else:
            frequency_dict[height] = 1
    
    # Find the frequency of the mode(s) by finding the largest
    # value in frequency_dict
    highest_freq = max(frequency_dict.values())
    
    # Create a list for mode values
    modes = []
    
    # From the dictionary, add element(s) to the modes list with max frequency
    for height, frequency in frequency_dict.items():
        if frequency == highest_freq:
            modes.append(height)

    # Return the mode list 
    return modes

# %% [markdown]
# 11. Use the above function to calculate the mode of the original height list.

# %%
# Your code here
find_mode(height_list)
# Out:
# [64]

# %% [markdown]
# 12.  Use the collections library and Counter object to extract the mode.

# %%
# Your code here
from collections import Counter

# insert python height list into Counter object
cnt_obj = Counter(height_list)

# counter object most common method to extracr mode
mode_counter = cnt_obj.most_common(1)[0][0]
mode_counter
# Out:
# 64

# %% [markdown]
# 13. Discuss the location of the mode relative to the mean and median. Could knowing the value of the mode independent of the mean and median be useful? Explain.

# %% [markdown]
# The mode is slightly lower than the mean and median values. It lies a little bit lower than the value of central tendency for the main part of the distribution.
